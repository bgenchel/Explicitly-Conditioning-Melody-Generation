# %%
import matplotlib.pyplot as plt
import json
import os
import os.path as op

simple_pitches_train_losses = json.load(open(op.join(os.getcwd(), 'simple_pitch_duration', 'runs', 'pitches', '2018-04-25_12:12:35', 'train_losses.json'), 'r'))

# %%
plt.plot(simple_pitches_train_losses)

# %%
ccp_pitches_train_losses = json.load(open(op.join(os.getcwd(), 'chord_conditioned_pitch', 'runs', 'pitches', '2018-04-25_12:08:12', 'train_losses.json'), 'r'))

# %%
plt.plot(ccp_pitches_train_losses)

# %%
ccp_pitches_train_losses_2 = json.load(open(op.join(os.getcwd(), 'chord_conditioned_pitch', 'runs', 'pitches', '2018-04-26_03:21:40', 'train_losses.json'), 'r'))

# %%
plt.plot(ccp_pitches_train_losses_2)

# %%
ccp_pitches_train_losses_3 = json.load(open(op.join(os.getcwd(), 'chord_conditioned_pitch', 'runs', 'pitches', '2018-04-26_03:32:09', 'train_losses.json'), 'r'))
plt.plot(ccp_pitches_train_losses_3)

# %%
ccp_durs_train_losses = json.load(open(op.join(os.getcwd(), 'chord_conditioned_pitch', 'runs', 'durations', '2018-04-26_03:41:59', 'train_losses.json'), 'r'))
plt.plot(ccp_durs_train_losses)

# %%
ccp_pitches_train_losses_4 = json.load(open(op.join(os.getcwd(), 'chord_conditioned_pitch', 'runs', 'pitches', '2018-04-26_03:35:55', 'train_losses.json'), 'r'))
plt.plot(ccp_pitches_train_losses_4)
